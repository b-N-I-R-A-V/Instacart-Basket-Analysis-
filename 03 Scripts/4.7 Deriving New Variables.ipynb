# %% [markdown]
# # Table of Contents
# 1. Importing Libraries
# 2. Importing Files
# 3. Creating a Crosstab
# 4. Creating a price-label function
# 5. Exercise 4.7 Answers
# 6. Exporting Dataframe

# %% [markdown]
# ## 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Imorting Files

# %%
# Setting Path
path = r'/Users/niravbariya/Documents/Data Science/CareerFoundry/Data Analytics Immersion/Achievement 4/04-04-2024 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %% [markdown]
# ## 03. Creating a Crosstab

# %%
crosstab = pd.crosstab(ords_prods_merge['days_since_prior_order'], ords_prods_merge['order_number'], dropna = False)

# %%
crosstab
# Out:
# order_number                 1       2       3       4       5       6   \
# days_since_prior_order
# 0.0                           0   20536   20441   17984   16438   16046
# 1.0                           0   31674   29950   28010   27092   25533
# 2.0                           0   46454   46264   43902   40729   40907
# 3.0                           0   61637   63388   59996   57882   56183
# 4.0                           0   76733   78861   73540   70519   66569
# 5.0                           0   88999   91741   86503   81859   77583
# 6.0                           0  120681  122871  114644  106764  100756
# 7.0                           0  184802  181656  167597  157442  143628
# 8.0                           0  112324  110742  102217   94945   87611
# 9.0                           0   73676   75379   68513   65045   58933
# 10.0                          0   62037   62457   57676   51916   49463
# 11.0                          0   55561   55918   51974   45512   42542
# ...

# %%
# Extracting a subset of the dataframe
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# ## 04. Creating a price-label function

# %%
# Define a function

def price_label(row):
  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# /var/folders/xd/gd6kszh506xbhlz9mv23vpxh0000gn/T/ipykernel_81251/4221219494.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
# counting frequency
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# most expensive product
df['prices'].max()
# Out:
# 14.8

# %%
# Using loc
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/xd/gd6kszh506xbhlz9mv23vpxh0000gn/T/ipykernel_81251/2858303388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# Applying loc to entire datafram
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range'] = 'Low-range product'

# %%
ords_prods_merge['price_range'].value_counts()
# Out:
# price_range
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# ### Using For loops

# %%
# finding frequency of the days_of_week
ords_prods_merge['orders_day_of_week'].value_counts()
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# adding the result column to the dataframe ords_prods_merge
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# ## 05.Exercise 4.7 Answers

# %%
# creating a for loop to assign busiest days for 0 and 1 and least busy for 3 and 4
result_2 = []
for value in ords_prods_merge['orders_day_of_week']:
    if (value == 0) or (value == 1):
        result_2.append('Busiest days')
    elif (value == 3) or (value == 4):
        result_2.append('Least busy days')
    else : result_2.append('Regularly busy days')

# %%
ords_prods_merge['busiest_days'] = result_2

# %%
# frequency count for busiest_days
ords_prods_merge['busiest_days'].value_counts()
# Out:
# busiest_days
# Regularly busy days    12916111
# Busiest days           11864412
# Least busy days         7624336
# Name: count, dtype: int64

# %% [markdown]
# The results are consistent with what we have observed previously for each individual day of week.

# %% [markdown]
# ### Identifying busiest hours of the day

# %%
ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#Creating the list result for busiest_period_of_day

result_3 = []
for value in ords_prods_merge['order_hour_of_day']:
    if value in range(9,16):
        result_3.append('Most orders')
    elif (value in range(0,6)) or (value == 23):
        result_3.append('Fewest orders')
    else : result_3.append('Average orders')

# %%
result_3
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
# ...

# %%
#Assigning busiest period of day to the dataframe
ords_prods_merge['busiest_period_of_day'] = result_3

# %%
# frequency of busiest_period_of_day
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       18582869
# Average orders    12823346
# Fewest orders       998644
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# ## 06. Exporting Dataframe

# %%
# Exporting the datafram

ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_new_var.pkl'))
